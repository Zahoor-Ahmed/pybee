# %%
import pybee as pb
pb.set_env()
# Out:
# 🔧 Interactive setup mode. Please fill in all configuration fields.
#
#
# ✅ Configuration saved to:
# C:\Users\iamza\.pybee_config.json
# You can manually edit this file later to update any values.

# %%
import pybee as pb
output = pb.run_shell(f"""
ls -l | head -5
                   """)

print(output)
# Out:
# total 121396
# -rw-r-----  1 root root        0 Apr 29  2024 =
# -rw-r--r--  1 root root 66154783 Apr 22 21:00 -
# -rw-r-----  1 root root        0 Apr 25 13:26 0
# -rw-r-----  1 root root        0 May 11 16:56 6000

# %%
import pybee as pb
output = pb.run_shell(f"""
hdfs dfsadmin -report|head;
                   """)

print(output)
# Out:
# Configured Capacity: 1125899906842624 (1.00 PB)
# Present Capacity: 1000000000000000 (909.49 TB)
# DFS Remaining: 450000000000000 (409.60 TB)
# DFS Used: 550000000000000 (500.00 TB)
# DFS Used%: 55.00%
# Replicated Blocks:
# 	Under replicated blocks: 2
# 	Blocks with corrupt replicas: 0
# 	Missing blocks: 1
# 	Missing blocks (with replication factor 1): 0

# %%
import pybee as pb
output, rows = pb.run_sql("desc table customers_sample_data",io=1)
# Out:
# +--------------------+------------+----------+
# |      col_name      | data_type  | comment  |
# +--------------------+------------+----------+
# | index              | string     | NULL     |
# | customer_id        | string     | NULL     |
# | first_name         | string     | NULL     |
# | last_name          | string     | NULL     |
# | company            | string     | NULL     |
# | city               | string     | NULL     |
# | country            | string     | NULL     |
# | phone_1            | string     | NULL     |
# | phone_2            | string     | NULL     |
# | email              | string     | NULL     |
# | subscription_date  | string     | NULL     |
# | website            | string     | NULL     |
# +--------------------+------------+----------+
# 12 rows selected

# %%
df = pb.text_to_df(output)
display(df)
# Out:
#              col_name data_type comment
# 0               index    string    NULL
# 1         customer_id    string    NULL
# 2          first_name    string    NULL
# 3           last_name    string    NULL
# 4             company    string    NULL
# 5                city    string    NULL
# 6             country    string    NULL
# 7             phone_1    string    NULL
# 8             phone_2    string    NULL
# 9               email    string    NULL
# 10  subscription_date    string    NULL
# 11            website    string    NULL

# %%
import pybee as pb
pb.upload_file("/opt/zam/tmp_files")
# Out:
# 1. Uploading file to the server . . . . . . . . . . . . . . . . . . . . . . . . ~ Done.

# %%
import pybee as pb
pb.download_file("/opt/zam/tmp_files/customers-100.csv")
# Out:
# 8. Downloading CSV file to local machine . . . . . . . . . . . . . . . . . . . . . . . . ~ Done.
# File saved to  C:\Users\iamza\Downloads\db_exports\customers-100_v1.csv
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# ...

# %%
import pybee as pb
df = pb.table_to_df("customers_sample_data")
# Out:
# 1. Fetching column headers . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ~ Done.
# 2. Exporting table to HDFS directory . . . . . . . . . . . . . . . . . . . . . . . . . . . . ~ Done.
# 3. Combining parts into a single CSV file  . . . . . . . . . . . . . . . . . . . . . . . . . ~ Done.
# 4. Removing files from HDFS  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ~ Done.
# 5. Changing file permissions . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ~ Done.
#
# Table customers_sample_data downloaded successfully in:
# "C:\Users\iamza\Downloads\db_exports"

# %%
import pybee as pb
pb.download_df("/opt/zam/tmp_files/customers-100.csv")
# Out:
# Table customers-100 downloaded successfully in:
# "C:\Users\iamza\Downloads\db_exports"
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# ...

# %%
import pybee as pb
import pandas as pd
df = pd.read_csv(r"C:\Users\iamza\Downloads\db_exports\customers-100.csv")
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
pb.df_to_Table(df)
# Out:
# 1: Writing DataFrame to a temporary CSV file . . . . . . . . . . . . . . . . . . . . ~ Done.
# 2: Uploading file to the server . . . . . . . . . . . . . . . . . . . . . . . . . .  ~ Done.
# 3: Removing file headers on the server . . . . . . . . . . . . . . . . . . . . . . . ~ Done.
# 4: Moving file to HDFS . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ~ Done.
# 5: Table creation started . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  ~ Done.
# 6. Truncating table before loading data. . . . . . . . . . . . . . . . . . . . . . . ~ Done.
# 7: Loading CSV data into the table . . . . . . . . . . . . . . . . . . . . . . . . . ~ Done.
#
# table_name = customers_sample_data
# +--------+------------------+-------------+------------+------------------+--------------------+----------------------+------------------+----------------------+---------------------------+--------------------+-----------------------------+
# ...

# %%
import pybee as pb
pb.run_sql("select * from customers_sample_data limit 10", log_enabled=0, io=1);
# Out:
# +--------+------------------+-------------+------------+------------------+-------------------------+-------------------------+-----------------------------+-------------------------+---------------------------+------------------------------+-----------------------------+
# | index  |   customer_id    | first_name  | last_name  |     company      |          city           |         country         |           phone_1           |         phone_2         |           email           |      subscription_date       |           website           |
# +--------+------------------+-------------+------------+------------------+-------------------------+-------------------------+-----------------------------+-------------------------+---------------------------+------------------------------+-----------------------------+
# ...

# %%
# %%sql
#
# select * from customers_sample_data limit 10
# Out:
# +--------+------------------+-------------+------------+------------------+-------------------------+-------------------------+-----------------------------+-------------------------+---------------------------+------------------------------+-----------------------------+
# | index  |   customer_id    | first_name  | last_name  |     company      |          city           |         country         |           phone_1           |         phone_2         |           email           |      subscription_date       |           website           |
# +--------+------------------+-------------+------------+------------------+-------------------------+-------------------------+-----------------------------+-------------------------+---------------------------+------------------------------+-----------------------------+
# ...
